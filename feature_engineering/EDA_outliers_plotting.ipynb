# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data loading

# %%
trainingset = pd.read_csv("C:/Users/esrio_0v2bwuf/Desktop/Master_AI/Data_Mining_Techniques/Assignments/Assignment2/Data-Mining-2/Data/training_set_VU_DM.csv")

# %%
testset = pd.read_csv("C:/Users/esrio_0v2bwuf/Desktop/Master_AI/Data_Mining_Techniques/Assignments/Assignment2/Data-Mining-2/Data/test_set_VU_DM.csv")

# %% [markdown]
# # Sanity check

# %%
trainingset.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score  ...  comp6_rate_percent_diff  \
# ...

# %%
trainingset.shape[0]
# Out:
# 4958347

# %%
testset.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-02-02 15:27:40       24                          216
# 1        1  2013-02-02 15:27:40       24                          216
# 2        1  2013-02-02 15:27:40       24                          216
# 3        1  2013-02-02 15:27:40       24                          216
# 4        1  2013-02-02 15:27:40       24                          216
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219     3180
# 1                      NaN                   NaN              219     5543
# 2                      NaN                   NaN              219    14142
# 3                      NaN                   NaN              219    22393
# 4                      NaN                   NaN              219    24194
#
#    prop_starrating  prop_review_score  ...  comp5_rate_percent_diff  \
# ...

# %%
testset.shape[0]
# Out:
# 4959183

# %% [markdown]
# # Combine training and test set

# %%
traintest = pd.concat([trainingset, testset], axis=0) #axis=0 means row wise concatenation

# %%
traintest.shape[0]
# Out:
# 9917530

# %%
traintest.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score  ...  comp6_rate_percent_diff  \
# ...

# %% [markdown]
# | Field | Data Type | Description |
# | --- | --- | --- |
# | srch_id | Integer | The ID of the search |
# | date_time | Date/time | Date and time of the search |
# | site_id | Integer | ID of the Expedia point of sale (i.e. Expedia.com, Expedia.co.uk, Expedia.co.jp, ..) |
# | visitor_location_country_id | Integer | The ID of the country the customer is located |
# | visitor_hist_starrating | Float | The mean star rating of hotels the customer has previously purchased; null signifies there is no purchase history on the customer |
# | visitor_hist_adr_usd | Float | The mean price per night (in US$) of the hotels the customer has previously purchased; null signifies there is no purchase history on the customer |
# | prop_country_id | Integer | The ID of the country the hotel is located in |
# | prop_id | Integer | The ID of the hotel |
# | prop_starrating | Integer | The star rating of the hotel, from 1 to 5, in increments of 1. A 0 indicates the property has no stars, the star rating is not known or cannot be publicized |
# | prop_review_score | Float | The mean customer review score for the hotel on a scale out of 5, rounded to 0.5 increments. A 0 means there have been no reviews, null that the information is not available |
# | prop_brand_bool | Integer | +1 if the hotel is part of a major hotel chain; 0 if it is an independent hotel |
# | prop_location_score1 | Float | A (first) score outlining the desirability of a hotel’s location |
# | prop_location_score2 | Float | A (second) score outlining the desirability of a hotel’s location |
# | prop_log_historical_price | Float | The logarithm of the mean price of the hotel over the last trading period. A 0 will occur if the hotel was not sold in that period |
# | price_usd | Float | Displayed price of the hotel for the given search. Note that different countries have different conventions regarding displaying taxes and fees and the value may be per night or for the whole stay |
# | promotion_flag | Integer | +1 if the hotel had a sale price promotion specifically displayed |
# | srch_destination_id | Integer | ID of the destination where the hotel search was performed |
# | srch_length_of_stay | Integer | Number of nights stay that was searched |
# | srch_booking_window | Integer | Number of days in the future the hotel stay started from the search date |
# | srch_adults_count | Integer | The number of adults specified in the hotel room |
# | srch_children_count | Integer | The number of (extra occupancy) children specified in the hotel room |
# | srch_room_count | Integer | Number of hotel rooms specified in the search |
# | srch_saturday_night_bool | Boolean | +1 if the stay includes a Saturday night, starts from Thursday with a length of stay is less than or equal to 4 nights (i.e. weekend); otherwise 0 |
# | srch_query_affinity_score | Float | The log of the probability a hotel will be clicked on in Internet searches (hence the values are negative) A null signifies there are no data (i.e. hotel did not register in any searches) |
# | orig_destination_distance | Float | Physical distance between the hotel and the customer at the time of search. A null means the distance could not be calculated |
# | random_bool | Boolean | +1 when the displayed sort was random, 0 when the normal sort order was displayed |
# | comp1_rate | Integer | +1 if Expedia has a lower price than competitor 1 for the hotel; 0 if the same; -1 if Expedia’s price is higher than competitor 1; null signifies there is no competitive data |
# | comp1_inv | Integer | +1 if competitor 1 does not have availability in the hotel; 0 if both Expedia and competitor 1 have availability; null signifies there is no competitive data |
# | comp1_rate_percent_diff | Float | The absolute percentage difference (if one exists) between Expedia and competitor 1’s price (Expedia’s price the denominator); null signifies there is no competitive data |
# | comp2_rate | | |
# | comp2_inv | | (same, for competitor 2 through 8) |
# | comp2_rate_percent_diff | | |
# | ... | | |
# | comp8_rate | | |
# | comp8_in | | |
# | comp8_rate_percent_diff | | |
# | position | Integer | Hotel position on Expedia’s search results page. This is only provided for the training data, but not the test data |
# | click_bool | Boolean | 1 if the user clicked on the property, 0 if not |
# | booking_bool | Boolean | 1 if the user booked the property, 0 if not |
# | gross_booking_usd | Float | Total value of the transaction. This can differ from the price_usd due to taxes, fees, conventions on multiple day bookings and purchase of a room type other than the one shown in the search |

# %% [markdown]
# # Data visualization/plots

# %%
#plot number of missing values in each column using bar plot matplotlib
missing_values = trainingset.isnull().sum().sort_values(ascending=False)

#create barplot
plt.figure(figsize=(12,8))  # Optional: You can set the figure size
missing_values.plot(kind='bar')

#rotate the x-axis labels
plt.xticks(rotation=85)
plt.title('Proportion of missing values in each column')
plt.xlabel('Columns')
plt.ylabel('Proportion of missing values')
plt.show()

# %%
#plot number of missing values in each column using bar plot matplotlib
missing_values = traintest.isnull().sum().sort_values(ascending=False)

#create barplot
plt.figure(figsize=(12,8))  # Optional: You can set the figure size
missing_values.plot(kind='bar')

#rotate the x-axis labels
plt.xticks(rotation=85)
plt.title('Proportion of missing values in each column')
plt.xlabel('Columns')
plt.ylabel('Proportion of missing values')
plt.show()

# %%
traintest.shape[1]
# Out:
# 54

# %% [markdown]
# # Missing values visualized

# %%
#create a scatter plot of the column gross_booking_usd against booking_bool
plt.figure(figsize=(12,8))
plt.scatter(traintest['gross_bookings_usd'], traintest['booking_bool'])
plt.xlabel('Gross booking in USD')
plt.ylabel('Booking bool')
plt.show()

# %%
#plot srch_query_affinity_score against booking_bool
plt.figure(figsize=(12,8))
plt.scatter(traintest['srch_query_affinity_score'], traintest['booking_bool'])
plt.xlabel('Search query affinity score')
plt.ylabel('Booking bool')
plt.show()

# %%
#plot click_bool against booking_bool
plt.figure(figsize=(12,8))
plt.scatter(traintest['click_bool'], traintest['booking_bool'])
plt.xlabel('Click bool')
plt.ylabel('Booking bool')
plt.show()

# %%
#plot prop_location_score1 against prop_location_score2
plt.figure(figsize=(12,8))
plt.scatter(trainingset['prop_location_score1'], trainingset['prop_location_score2'])
plt.xlabel('Prop location score 1')
plt.ylabel('Prop location score 2')
plt.show()

# %%
#check to see in descending order the missing values of orig_desination_distance and prop_country_id

missing_values = trainingset.groupby('prop_country_id')['orig_destination_distance'].apply(lambda x: x.isnull().all())
missing_country_ids = missing_values[missing_values == True].index.tolist()

print(missing_country_ids)
# Out:
# [51, 62, 89, 108, 135, 165, 190]

# %%
missing_values
# Out:
# prop_country_id
# 1      False
# 2      False
# 4      False
# 7      False
# 9      False
#        ...
# 224    False
# 225    False
# 226    False
# 229    False
# 230    False
# Name: orig_destination_distance, Length: 172, dtype: bool

# %% [markdown]
# # Outliers (barplot)

# %%
#create a boxplot of each column to see outliers in the data
plt.figure(figsize=(12,8))
trainingset.boxplot()
plt.xticks(rotation=85)
plt.show()

# %%
#create a boxplot of each column to see outliers in the data
plt.figure(figsize=(12,8))
trainingset.drop('price_usd', axis = 1).boxplot()
plt.xticks(rotation=85)
plt.show()

# %%
#create a dataset without the price_usd column, all variables with comp in it
no_comp = [col for col in trainingset.columns if 'comp' not in col]
df_new = trainingset[no_comp]

plt.figure(figsize=(12,8))
df_new.drop('price_usd', axis = 1).boxplot()
plt.xticks(rotation=85)
plt.show()

# %%
#also drop price_usd column and gross_bookings_usd column
df_newest = df_new.drop(['price_usd', 'gross_bookings_usd', 'srch_id', 'prop_id', 'srch_destination_id'], axis = 1)

plt.figure(figsize=(12,8))
df_newest.boxplot()
plt.xticks(rotation=85)
plt.show()

# %% [markdown]
# # individual boxplots

# %%
#print columnnames traintest
traintest.columns
# Out:
# Index(['srch_id', 'date_time', 'site_id', 'visitor_location_country_id',
#        'visitor_hist_starrating', 'visitor_hist_adr_usd', 'prop_country_id',
#        'prop_id', 'prop_starrating', 'prop_review_score', 'prop_brand_bool',
#        'prop_location_score1', 'prop_location_score2',
#        'prop_log_historical_price', 'position', 'price_usd', 'promotion_flag',
#        'srch_destination_id', 'srch_length_of_stay', 'srch_booking_window',
#        'srch_adults_count', 'srch_children_count', 'srch_room_count',
#        'srch_saturday_night_bool', 'srch_query_affinity_score',
#        'orig_destination_distance', 'random_bool', 'comp1_rate', 'comp1_inv',
#        'comp1_rate_percent_diff', 'comp2_rate', 'comp2_inv',
#        'comp2_rate_percent_diff', 'comp3_rate', 'comp3_inv',
#        'comp3_rate_percent_diff', 'comp4_rate', 'comp4_inv',
#        'comp4_rate_percent_diff', 'comp5_rate', 'comp5_inv',
#        'comp5_rate_percent_diff', 'comp6_rate', 'comp6_inv',
# ...

# %% [markdown]
# ### scatter plot against date only training set

# %%
#Drop columns for the outlier detection in train and test set
cols_to_drop = ['srch_id', 'site_id',  'visitor_location_country_id', 'prop_country_id', 'prop_id', 'prop_brand_bool', 'promotion_flag' , 'srch_destination_id', 'srch_saturday_night_bool', 'srch_query_affinity_score', 'random_bool', 'position',  'click_bool', 'booking_bool']

comp_cols_inv = [f'comp{i}_inv' for i in range(1, 9)]
cols_to_drop.extend(comp_cols_inv)

comp_cols_rate = [f'comp{i}_rate' for i in range(1, 9)]
cols_to_drop.extend(comp_cols_rate)

#drop the columns:
df_outliers = trainingset.drop(cols_to_drop, axis = 1)

# Reset index
df_outliers = df_outliers.reset_index(drop=True)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure the date column is in datetime format
df_outliers['date_time'] = pd.to_datetime(df_outliers['date_time'])

# For each column in the DataFrame, create a scatter plot against the date
for column in df_outliers.columns:
    if column != 'date_time':  # Skip the date column itself
        plt.figure(figsize=(10, 5))
        plt.scatter(df_outliers['date_time'], df_outliers[column])
        plt.title(f'{column} over time')
        plt.xlabel('Date')
        plt.ylabel(column)
        plt.show()

# %% [markdown]
# ### plot scatter with against date

# %%
#Drop columns for the outlier detection in train and test set
cols_to_drop = ['srch_id', 'site_id',  'visitor_location_country_id', 'prop_country_id', 'prop_id', 'prop_brand_bool', 'promotion_flag' , 'srch_destination_id', 'srch_saturday_night_bool', 'srch_query_affinity_score', 'random_bool', 'position',  'click_bool', 'booking_bool']

comp_cols_inv = [f'comp{i}_inv' for i in range(1, 9)]
cols_to_drop.extend(comp_cols_inv)

comp_cols_rate = [f'comp{i}_rate' for i in range(1, 9)]
cols_to_drop.extend(comp_cols_rate)

#drop the columns:
df_outliers = traintest.drop(cols_to_drop, axis = 1)

# Reset index
df_outliers = df_outliers.reset_index(drop=True)

# %%
# Ensure the date column is in datetime format
df_outliers['date_time'] = pd.to_datetime(df_outliers['date_time'])

# For each column in the DataFrame, create a scatter plot against the date
for column in df_outliers.columns:
    if column != 'date_time':  # Skip the date column itself
        plt.figure(figsize=(10, 5))
        plt.scatter(df_outliers['date_time'], df_outliers[column])
        plt.title(f'{column} over time')
        plt.xlabel('Date')
        plt.ylabel(column)
        plt.show()

# %% [markdown]
# ### also dorp date, create boxplots instead

# %%
#Drop columns for the outlier detection in train and test set
cols_to_drop = ['srch_id', 'date_time', 'site_id',  'visitor_location_country_id', 'prop_country_id', 'prop_id', 'prop_brand_bool', 'promotion_flag' , 'srch_destination_id', 'srch_saturday_night_bool', 'srch_query_affinity_score', 'random_bool', 'position',  'click_bool', 'booking_bool']

comp_cols_inv = [f'comp{i}_inv' for i in range(1, 9)]
cols_to_drop.extend(comp_cols_inv)

comp_cols_rate = [f'comp{i}_rate' for i in range(1, 9)]
cols_to_drop.extend(comp_cols_rate)

#drop the columns:
df_outliers = traintest.drop(cols_to_drop, axis = 1)

# Reset index
df_outliers = df_outliers.reset_index(drop=True)

# %%
# For each column in the DataFrame, create a boxplot
for column in df_outliers.columns:
    plt.figure(figsize=(5, 5))
    sns.boxplot(y=df_outliers[column])
    plt.title(column)
    plt.show()
